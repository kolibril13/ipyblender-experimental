# %%
from ipyblender_experimental import BlenderWidget

# %%
BlenderWidget()
# Out:
# BlenderWidget()
# Fra:1 Mem:84.10M (Peak 84.10M) | Time:00:00.00 | Syncing Light
# Fra:1 Mem:84.10M (Peak 84.10M) | Time:00:00.00 | Syncing Camera
# Fra:1 Mem:84.11M (Peak 84.11M) | Time:00:00.00 | Syncing Torus.053
# Fra:1 Mem:85.45M (Peak 85.45M) | Time:00:00.00 | Rendering 1 / 64 samples
# Fra:1 Mem:84.54M (Peak 85.45M) | Time:00:00.12 | Rendering 26 / 64 samples
# Fra:1 Mem:84.60M (Peak 85.45M) | Time:00:00.22 | Rendering 51 / 64 samples
# Fra:1 Mem:84.54M (Peak 85.45M) | Time:00:00.28 | Rendering 64 / 64 samples
# Saved: 'test.png'
#  Time: 00:00.32 (Saving: 00:00.03)
#
# Fra:1 Mem:85.38M (Peak 85.38M) | Time:00:00.00 | Syncing Light
# Fra:1 Mem:85.38M (Peak 85.38M) | Time:00:00.00 | Syncing Camera
# Fra:1 Mem:85.38M (Peak 85.38M) | Time:00:00.00 | Syncing Torus.054
# Fra:1 Mem:86.73M (Peak 86.73M) | Time:00:00.00 | Rendering 1 / 64 samples
# Fra:1 Mem:85.75M (Peak 86.73M) | Time:00:00.12 | Rendering 26 / 64 samples
# ...
