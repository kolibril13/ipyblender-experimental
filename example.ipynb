# %%
from ipyblender_experimental import BlenderWidget
BlenderWidget()
# Out:
# Device with name Apple M1 supports metal minimum requirements
# BlenderWidget()
# Old value: 0
# New value: 1
# --------------------------
# METAL API - DETECTED GPU: Apple M1
# Fra:1 Mem:18.18M (Peak 19.01M) | Time:00:00.08 | Syncing Light
# Fra:1 Mem:18.18M (Peak 19.01M) | Time:00:00.08 | Syncing Camera
# Fra:1 Mem:18.19M (Peak 19.01M) | Time:00:00.08 | Syncing Sphere
# Fra:1 Mem:18.43M (Peak 19.01M) | Time:00:00.10 | Syncing Camera.001
# Fra:1 Mem:18.43M (Peak 19.01M) | Time:00:00.10 | Syncing light
# Fra:1 Mem:18.44M (Peak 19.01M) | Time:00:00.10 | Rendering 1 / 64 samples
# Fra:1 Mem:18.49M (Peak 19.01M) | Time:00:00.21 | Rendering 26 / 64 samples
# Fra:1 Mem:18.49M (Peak 19.01M) | Time:00:00.27 | Rendering 51 / 64 samples
# Fra:1 Mem:18.55M (Peak 19.01M) | Time:00:00.30 | Rendering 64 / 64 samples
# Saved: 'test_sphere.png'
#  Time: 00:00.42 (Saving: 00:00.11)
#
# Old value: 1
# New value: 2
# --------------------------
# ...
