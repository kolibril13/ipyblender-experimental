# %%
from ipyblender_experimental import BlenderInteractiveWidget
# Out:
# Device with name Apple M1 supports metal minimum requirements

# %%
b = BlenderInteractiveWidget()
b
# Out:
# BlenderInteractiveWidget()

# %%
b.count = 0
