# %%
import bpy
from IPython.display import display, Image

path = "test.png"
bpy.context.scene.render.resolution_x = 500
bpy.context.scene.render.resolution_y = 200
bpy.ops.render.render()
bpy.data.images["Render Result"].save_render(filepath=path)
display(Image(filename=path))
# Out:
# Device with name Apple M1 supports metal minimum requirements
# METAL API - DETECTED GPU: Apple M1
# Fra:1 Mem:13.43M (Peak 14.25M) | Time:00:00.08 | Syncing Cube
# Fra:1 Mem:13.61M (Peak 14.25M) | Time:00:00.09 | Syncing Light
# Fra:1 Mem:13.61M (Peak 14.25M) | Time:00:00.09 | Syncing Camera
# Fra:1 Mem:13.61M (Peak 14.25M) | Time:00:00.09 | Rendering 1 / 64 samples
# Fra:1 Mem:13.71M (Peak 14.25M) | Time:00:00.16 | Rendering 26 / 64 samples
# Fra:1 Mem:13.71M (Peak 14.25M) | Time:00:00.19 | Rendering 51 / 64 samples
# Fra:1 Mem:13.71M (Peak 14.25M) | Time:00:00.21 | Rendering 64 / 64 samples
