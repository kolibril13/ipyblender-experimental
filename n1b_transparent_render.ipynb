# %%
import bpy
from IPython.display import display, Image

# Set render resolution
bpy.context.scene.render.resolution_x = 500
bpy.context.scene.render.resolution_y = 200

# Enable RGBA (including alpha channel) and set the alpha mode to 'TRANSPARENT'
bpy.context.scene.render.image_settings.file_format = 'PNG'
bpy.context.scene.render.image_settings.color_mode = 'RGBA'
bpy.context.scene.render.film_transparent = True

# Render the scene
bpy.ops.render.render()

# Save the render with transparent background
path = "test.png"
bpy.data.images['Render Result'].save_render(filepath=path)


# Display the image
display(Image(filename=path))
# Out:
# Device with name Apple M1 supports metal minimum requirements
# METAL API - DETECTED GPU: Apple M1
# Fra:1 Mem:13.43M (Peak 14.25M) | Time:00:00.10 | Syncing Cube
# Fra:1 Mem:13.61M (Peak 14.25M) | Time:00:00.11 | Syncing Light
# Fra:1 Mem:13.61M (Peak 14.25M) | Time:00:00.11 | Syncing Camera
# Fra:1 Mem:13.61M (Peak 14.25M) | Time:00:00.11 | Rendering 1 / 64 samples
# Fra:1 Mem:13.71M (Peak 14.25M) | Time:00:00.19 | Rendering 26 / 64 samples
# Fra:1 Mem:13.71M (Peak 14.25M) | Time:00:00.22 | Rendering 51 / 64 samples
# Fra:1 Mem:13.71M (Peak 14.25M) | Time:00:00.24 | Rendering 64 / 64 samples
