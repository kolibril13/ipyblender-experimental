# %%
import bpy
import bmesh

blend_file_path = "nodegroup_network.blend"
bpy.ops.wm.open_mainfile(filepath=blend_file_path)
# Out:
# Read prefs: "/Users/jan-hendrik/Library/Application Support/Blender/4.1/config/userpref.blend"Read blend: "/Users/jan-hendrik/projects/ipyblender-experimental/nodegroup_network.blend"Info: Saved "nodegroup_network.blend"
# Info: Saved "nodegroup_network.blend"
# Info: Saved "nodegroup_network.blend"
# Info: Saved "nodegroup_network.blend"
# Info: Saved "nodegroup_network.blend"
# {'FINISHED'}

# %% [markdown]
# ![image.png](attachment:6d1fc8bb-930a-4a0d-ba46-aa61e14214c7.png)
